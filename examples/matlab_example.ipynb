# %% [markdown]
# Explore EEGLAb's .set file to enhance conversion expeirence.

# %%
from scipy.io import loadmat

# %%
# load the example data
data = loadmat('wristbandEMG_truncated.set')
keys = data.keys()
print(keys)
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'setname', 'filename', 'filepath', 'subject', 'group', 'condition', 'session', 'comments', 'nbchan', 'trials', 'pnts', 'srate', 'xmin', 'xmax', 'times', 'data', 'icaact', 'icawinv', 'icasphere', 'icaweights', 'icachansind', 'chanlocs', 'urchanlocs', 'chaninfo', 'ref', 'event', 'urevent', 'eventdescription', 'epoch', 'epochdescription', 'reject', 'stats', 'specdata', 'specicaact', 'splinefile', 'icasplinefile', 'dipfit', 'history', 'saved', 'etc', 'run', 'datfile', 'roi', 'BIDS', 'task'])

# %%
data['event']
# Out:
# array([[(array([[0.5]]), array([[10000]], dtype=uint16), array([], shape=(1, 0), dtype=float64), array([], dtype='<U1'), array(['boundary'], dtype='<U8'), array([], shape=(1, 0), dtype=float64)),
#         (array([[4547]], dtype=uint16), array([[39036]], dtype=uint16), array([[14547]], dtype=uint16), array(['prompt/the quick brown fox jumps over a lazy dog\\n'],
#               dtype='<U50'), array(['161'], dtype='<U3'), array([[1]], dtype=uint8))                                                                                  ,
#         (array([[9516]], dtype=uint16), array([[0]], dtype=uint8), array([[19516]], dtype=uint16), array(['key/t'], dtype='<U5'), array(['28'], dtype='<U2'), array([[2]], dtype=uint8)),
#         (array([[9812]], dtype=uint16), array([[0]], dtype=uint8), array([[19812]], dtype=uint16), array(['key/h'], dtype='<U5'), array(['16'], dtype='<U2'), array([[3]], dtype=uint8)),
# ...

# %%
data['chanlocs']
# Out:
# array([[(array(['emg0_left'], dtype='<U9'), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([[0]], dtype=uint8), array([[0]], dtype=uint8), array([[0]], dtype=uint8), array([[0]], dtype=uint8), array([[0]], dtype=uint8), array(['EMG'], dtype='<U3'), array([], dtype='<U1'), array([], shape=(0, 0), dtype=uint8)),
#         (array(['emg1_left'], dtype='<U9'), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([[0]], dtype=uint8), array([[0]], dtype=uint8), array([[0]], dtype=uint8), array([[0]], dtype=uint8), array([[0]], dtype=uint8), array(['EMG'], dtype='<U3'), array([], dtype='<U1'), array([], shape=(1, 0), dtype=float64)),
# ...
