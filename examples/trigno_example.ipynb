# %% [markdown]
# # Setup and Imports
# Import required libraries (os, emgio.EMG, matplotlib.pyplot) and set up the environment for EMG data processing.

# %%
# Import required libraries
import os
from emgio import EMG
import matplotlib.pyplot as plt

# Set up the environment for EMG data processing
# (No additional setup required for this example)

# %% [markdown]
# # Load EMG Data
# Load EMG data from a Trigno CSV file using the EMGIO package's from_file method with the 'trigno' importer.

# %%
# Load EMG Data

# Sample data path - replace with your actual data path
data_path = '/Users/yahya/Documents/git/emgio/examples/trigno_sample.csv'  # Update this path to your Trigno CSV file

if not os.path.exists(data_path):
    print(f"Sample file not found: {data_path}")
    print("Please update the data_path variable with your Trigno CSV file path.")
else:
    # Load the data using Trigno importer
    print("Loading EMG data...")
    emg = EMG.from_file(data_path, importer='trigno')

    # Print available channels
    print("\nAvailable channels:")
    for ch_name, ch_info in emg.channels.items():
        print(f"- {ch_name} ({ch_info['type']})")
        print(f"  Sampling rate: {ch_info['sampling_freq']} Hz")
        print(f"  Unit: {ch_info['unit']}")
# Out:
# Loading EMG data...
#
# Available channels:
# - Mini sensor 10: EMG 10 (EMG)
#   Sampling rate: 1259.259 Hz
#   Unit: V
# - Mini sensor 10: ACC.X 10 (ACC)
#   Sampling rate: 148.1481 Hz
#   Unit: g
# - Mini sensor 10: ACC.Y 10 (ACC)
#   Sampling rate: 148.1481 Hz
#   Unit: g
# - Mini sensor 10: ACC.Z 10 (ACC)
#   Sampling rate: 148.1481 Hz
#   Unit: g
# - Mini sensor 10: GYRO.X 10 (GYRO)
#   Sampling rate: 148.1481 Hz
#   Unit: °/s
# - Mini sensor 10: GYRO.Y 10 (GYRO)
#   Sampling rate: 148.1481 Hz
#   Unit: °/s
# - Mini sensor 10: GYRO.Z 10 (GYRO)
#   Sampling rate: 148.1481 Hz
#   Unit: °/s
# - Mini sensor 11: EMG 11 (EMG)
#   Sampling rate: 1259.259 Hz
#   Unit: V
# - Mini sensor 11: ACC.X 11 (ACC)
#   Sampling rate: 148.1481 Hz
#   Unit: g
# - Mini sensor 11: ACC.Y 11 (ACC)
#   Sampling rate: 148.1481 Hz
#   Unit: g
# - Mini sensor 11: ACC.Z 11 (ACC)
#   Sampling rate: 148.1481 Hz
#   Unit: g
# - Mini sensor 11: GYRO.X 11 (GYRO)
#   Sampling rate: 148.1481 Hz
#   Unit: °/s
# - Mini sensor 11: GYRO.Y 11 (GYRO)
#   Sampling rate: 148.1481 Hz
#   Unit: °/s
# - Mini sensor 11: GYRO.Z 11 (GYRO)
#   Sampling rate: 148.1481 Hz
#   Unit: °/s

# %% [markdown]
# # Channel Information and Selection
# Display available channels and their properties (type, sampling rate, unit). Select and filter EMG channels from the dataset.

# %%
# Channel Information and Selection

# Display available channels and their properties (type, sampling rate, unit)
print("\nAvailable channels:")
for ch_name, ch_info in emg.channels.items():
    print(f"- {ch_name} ({ch_info['type']})")
    print(f"  Sampling rate: {ch_info['sampling_freq']} Hz")
    print(f"  Unit: {ch_info['unit']}")

# Select and filter EMG channels from the dataset
emg_channels = [ch for ch, info in emg.channels.items() if info['type'] == 'EMG']
emg.select_channels(emg_channels)
# Out:
# Available channels:
# - Mini sensor 10: EMG 10 (EMG)
#   Sampling rate: 1259.259 Hz
#   Unit: V
# - Mini sensor 10: ACC.X 10 (ACC)
#   Sampling rate: 148.1481 Hz
#   Unit: g
# - Mini sensor 10: ACC.Y 10 (ACC)
#   Sampling rate: 148.1481 Hz
#   Unit: g
# - Mini sensor 10: ACC.Z 10 (ACC)
#   Sampling rate: 148.1481 Hz
#   Unit: g
# - Mini sensor 10: GYRO.X 10 (GYRO)
#   Sampling rate: 148.1481 Hz
#   Unit: °/s
# - Mini sensor 10: GYRO.Y 10 (GYRO)
#   Sampling rate: 148.1481 Hz
#   Unit: °/s
# - Mini sensor 10: GYRO.Z 10 (GYRO)
#   Sampling rate: 148.1481 Hz
#   Unit: °/s
# - Mini sensor 11: EMG 11 (EMG)
#   Sampling rate: 1259.259 Hz
#   Unit: V
# - Mini sensor 11: ACC.X 11 (ACC)
#   Sampling rate: 148.1481 Hz
#   Unit: g
# - Mini sensor 11: ACC.Y 11 (ACC)
#   Sampling rate: 148.1481 Hz
#   Unit: g
# - Mini sensor 11: ACC.Z 11 (ACC)
#   Sampling rate: 148.1481 Hz
#   Unit: g
# - Mini sensor 11: GYRO.X 11 (GYRO)
#   Sampling rate: 148.1481 Hz
#   Unit: °/s
# - Mini sensor 11: GYRO.Y 11 (GYRO)
#   Sampling rate: 148.1481 Hz
#   Unit: °/s
# - Mini sensor 11: GYRO.Z 11 (GYRO)
#   Sampling rate: 148.1481 Hz
#   Unit: °/s

# %% [markdown]
# # Signal Visualization
# Create visualization of the EMG signals using matplotlib, showing the first 5 seconds of data with proper titles and labels.

# %%
# Signal Visualization

# Plot the first 5 seconds of EMG data
print("\nPlotting EMG signals...")
emg.plot_signals(time_range=(0, 5))
plt.show()
# Out:
# Plotting EMG signals...

# %% [markdown]
# # Export to EDF Format
# Export the processed EMG data to EDF format and save channel metadata to a TSV file.

# %%
# Export to EDF Format

# Define the output path for the EDF file
output_path = 'trigno_emg.edf'

# Export the processed EMG data to EDF format
print(f"\nExporting to EDF: {output_path}")
emg.to_edf(output_path)

# Save channel metadata to a TSV file
channels_metadata_path = f"{os.path.splitext(output_path)[0]}_channels.tsv"
print(f"Channels metadata saved to: {channels_metadata_path}")

print("Export complete!")
# Out:
# Exporting to EDF: trigno_emg.edf
# Channels metadata saved to: trigno_emg_channels.tsv
# Export complete!
# /opt/homebrew/anaconda3/envs/torch-sci/lib/python3.10/site-packages/pyedflib/edfwriter.py:124: UserWarning: Physical minimum for channel 0 (Mini sensor 10: ) is -0.00253402, which has 11 chars, however, EDF+ can only save 8 chars, will be truncated to -0.00253, some loss of precision is to be expected
#   warnings.warn('Physical minimum for channel {} ({}) is {}, which has {} chars, '\
# /opt/homebrew/anaconda3/envs/torch-sci/lib/python3.10/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 0 (Mini sensor 10: ) is 0.003067445, which has 11 chars, however, EDF+ can only save 8 chars, will be truncated to 0.003067, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /opt/homebrew/anaconda3/envs/torch-sci/lib/python3.10/site-packages/pyedflib/edfwriter.py:124: UserWarning: Physical minimum for channel 1 (Mini sensor 11: ) is -0.0003529869, which has 13 chars, however, EDF+ can only save 8 chars, will be truncated to -0.00035, some loss of precision is to be expected
#   warnings.warn('Physical minimum for channel {} ({}) is {}, which has {} chars, '\
# /opt/homebrew/anaconda3/envs/torch-sci/lib/python3.10/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 1 (Mini sensor 11: ) is 0.0002952468, which has 12 chars, however, EDF+ can only save 8 chars, will be truncated to 0.000295, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
